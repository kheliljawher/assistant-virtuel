# %% [markdown]
# # Expedia Tunis

# %%
# Web scraping, pickle imports
import requests
from bs4 import BeautifulSoup
import pickle
import re

# %%
urls=['https://www.expedia.fr/Hotel-Search?adults=2&destination=Tunis%2C%20Tunisie&endDate=2020-03-31&latLong=36.798985%2C10.175961&regionId=6025910&rooms=1&semdtl=&sort=RECOMMENDED&startDate=2020-03-30&theme=&useRewards=true&userIntent']

# %%
def url_to_transcript(url):
    response= requests.get(url)
    soup = BeautifulSoup(response.content,"html.parser")

    regex = re.compile('floatlef')
    hotel_name=soup.find_all('span',attrs={'class': 'sr-hotel__name'})  
    hotel_adress=soup.find_all('a',attrs={'class': 'bui-link'})  
    hotel_desc=soup.find_all('div',attrs={'class': 'hotel_desc'})
    rating=soup.find_all('div',attrs={'class': 'bui-review-score__badge'})
    
        
    return hotel_name,hotel_adress,hotel_desc

# %%
response= requests.get('https://www.expedia.fr/Hotel-Search?ICMCID=Meta.tripa.Expedia_TMA-DM&ICMDTL=htl.17322404.taid.11951492...testslice..clickid.Xm-0pgokKIMAAEbYGxcAAAEJ_2020-03-29_2020-03-30_1584395430202.AUDID..defdate.1&SC=2&adults=2&endDate=2020-03-30&mctc=9&paandi=true&regionId=3570&selected=17322404&semdtl=&sort=RECOMMENDED&startDate=2020-03-29&theme=&trv_bp=205.28&trv_curr=TND&trv_di=T&trv_mbl=M&trv_tax=18.67&useRewards=true&userIntent')
soup = BeautifulSoup(response.content,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" data-language="fr_FR" data-version="v2.229.1.c7791054772f1fe8049503c5967f3e68d151788e" dir="ltr" lang="fr">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8">
# <link href="//a.intentmedia.net" rel="dns-prefetch"/>
# <link href="//images.trvl-media.com" rel="dns-prefetch"/>
# <link href="//a.travel-assets.com/" rel="dns-prefetch"/>
# <link href="//b.travel-assets.com/" rel="dns-prefetch"/>
# <link href="//c.travel-assets.com/" rel="dns-prefetch"/>
# <title>Robot ou pas robot ?</title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon" sizes="16x16 32x32" type="image/x-icon"/>
# <link href="/favicon.ico" rel="icon" sizes="16x16 32x32" type="image/x-icon"/>
# <script src="//b.travel-assets.com/uitoolkit/2-229/c7791054772f1fe8049503c5967f3e68d151788e/core/js/uitk-lib-bundle-min.js"></script>
# <!--[if IE 8]>
# ...

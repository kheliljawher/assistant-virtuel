# %% [markdown]
# #  Booking Sousse & TABARKA

# %%
# Web scraping, pickle imports
import requests
from bs4 import BeautifulSoup
import pickle
import re

# %%
urlSousse=['https://www.booking.com/searchresults.fr.html?label=gen173nr-1FCAEoggI46AdIM1gEaOIBiAEBmAENuAEXyAEM2AEB6AEB-AELiAIBqAIDuAK_vL7zBcACAQ&sid=5a7f5b6c02fd8206bf3197598e875367&sb=1&src=searchresults&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.fr.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIM1gEaOIBiAEBmAENuAEXyAEM2AEB6AEB-AELiAIBqAIDuAK_vL7zBcACAQ%3Bsid%3D5a7f5b6c02fd8206bf3197598e875367%3Btmpl%3Dsearchresults%3Bac_click_type%3Db%3Bac_position%3D1%3Bclass_interval%3D1%3Bdest_id%3D3593%3Bdest_type%3Dregion%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D2%3Bgroup_children%3D0%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Braw_dest_type%3Dregion%3Broom1%3DA%252CA%3Bsb_price_type%3Dtotal%3Bsearch_selected%3D1%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dindex%3Bsrc_elem%3Dsb%3Bsrpvid%3D711e6e68c21a0030%3Bss%3DDjerba%252C%2520Tunisie%3Bss_all%3D0%3Bss_raw%3Djerba%3Bssb%3Dempty%3Bsshis%3D0%3Btop_ufis%3D1%26%3B&ss=Sousse%2C+Gouvernorat+de+Sousse%2C+Tunisie&is_ski_area=&ssne=Djerba&ssne_untouched=Djerba&checkin_year=&checkin_month=&checkout_year=&checkout_month=&group_adults=2&group_children=0&no_rooms=1&from_sf=1&ss_raw=sousse&ac_position=0&ac_langcode=fr&ac_click_type=b&dest_id=-731250&dest_type=city&place_id_lat=35.82883&place_id_lon=10.64053&search_pageview_id=711e6e68c21a0030&search_selected=true&search_pageview_id=711e6e68c21a0030&ac_suggestion_list_length=5&ac_suggestion_theme_list_length=0',
'https://www.booking.com/searchresults.fr.html?aid=304142&label=gen173nr-1FCAEoggI46AdIM1gEaOIBiAEBmAENuAEXyAEM2AEB6AEB-AELiAIBqAIDuAK_vL7zBcACAQ&sid=5a7f5b6c02fd8206bf3197598e875367&tmpl=searchresults&ac_click_type=b&ac_position=0&class_interval=1&dest_id=-731250&dest_type=city&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=0cf56ef4211200b5&ss=Sousse%2C%20Gouvernorat%20de%20Sousse%2C%20Tunisie&ss_all=0&ss_raw=sousse&ssb=empty&sshis=0&ssne=Djerba&ssne_untouched=Djerba&top_ufis=1&rows=25&offset=25',
'https://www.booking.com/searchresults.fr.html?aid=304142&label=gen173nr-1FCAEoggI46AdIM1gEaOIBiAEBmAENuAEXyAEM2AEB6AEB-AELiAIBqAIDuAK_vL7zBcACAQ&sid=5a7f5b6c02fd8206bf3197598e875367&tmpl=searchresults&ac_click_type=b&ac_position=0&class_interval=1&dest_id=-731250&dest_type=city&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=c8426f08d0a6006f&ss=Sousse%2C%20Gouvernorat%20de%20Sousse%2C%20Tunisie&ss_raw=sousse&ssb=empty&ssne=Djerba&ssne_untouched=Djerba&top_ufis=1&rows=25&offset=50',
          'https://www.booking.com/searchresults.fr.html?aid=304142&label=gen173nr-1FCAEoggI46AdIM1gEaOIBiAEBmAENuAEXyAEM2AEB6AEB-AELiAIBqAIDuAK_vL7zBcACAQ&sid=5a7f5b6c02fd8206bf3197598e875367&sb=1&src=searchresults&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.fr.html%3Faid%3D304142%3Blabel%3Dgen173nr-1FCAEoggI46AdIM1gEaOIBiAEBmAENuAEXyAEM2AEB6AEB-AELiAIBqAIDuAK_vL7zBcACAQ%3Bsid%3D5a7f5b6c02fd8206bf3197598e875367%3Btmpl%3Dsearchresults%3Bac_click_type%3Db%3Bac_position%3D0%3Bclass_interval%3D1%3Bdest_id%3D-731250%3Bdest_type%3Dcity%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D2%3Bgroup_children%3D0%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Braw_dest_type%3Dcity%3Broom1%3DA%252CA%3Bsb_price_type%3Dtotal%3Bsearch_selected%3D1%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dsearchresults%3Bsrc_elem%3Dsb%3Bsrpvid%3D82907132e1a40146%3Bss%3DSousse%252C%2520Gouvernorat%2520de%2520Sousse%252C%2520Tunisie%3Bss_all%3D0%3Bss_raw%3Dsousse%3Bssb%3Dempty%3Bsshis%3D0%3Bssne%3DDjerba%3Bssne_untouched%3DDjerba%3Btop_ufis%3D1%26%3B&ss=Tabarka%2C+Jendouba%2C+Tunisie&is_ski_area=&ssne=Sousse&ssne_untouched=Sousse&city=-731250&checkin_year=&checkin_month=&checkout_year=&checkout_month=&group_adults=2&group_children=0&no_rooms=1&from_sf=1&ss_raw=taba&ac_position=0&ac_langcode=fr&ac_click_type=b&dest_id=-731294&dest_type=city&place_id_lat=36.954399&place_id_lon=8.75806&search_pageview_id=82907132e1a40146&search_selected=true&search_pageview_id=82907132e1a40146&ac_suggestion_list_length=5&ac_suggestion_theme_list_length=0']

# %%
def url_to_transcript(url):
    response= requests.get(url)
    soup = BeautifulSoup(response.content,"html.parser")

    regex = re.compile('floatlef')
    hotel_name=soup.find_all('span',attrs={'class': 'sr-hotel__name'})  
    hotel_adress=soup.find_all('a',attrs={'class': 'bui-link'})  
    distance=soup.find_all('span',attrs={'data-bui-component': 'Tooltip','data-tooltip-position':'top'})
    hotel_desc=soup.find_all('div',attrs={'class': 'hotel_desc'})
    detail=soup.find_all('a',attrs={'class': 'hotel_name_link url'})

    
        
    return hotel_name,hotel_adress,distance,hotel_desc,detail

# %%
booking = [url_to_transcript(u) for u in urlSousse]

# %%
hotel_name=[]
hotel_adress=[]
distance=[]
description=[]
details=[]
for item in booking:
    hotel_name.append(item[0])
    hotel_adress.append(item[1])
    distance.append(item[2])
    description.append(item[3])
    details.append(item[4])

# %%
len(hotel_name[1])
# Out:
# 25

# %%
x=len(hotel_name[0])+4
hotel_name=hotel_name[0]+hotel_name[1]+hotel_name[2]+hotel_name[3]
hotel_adress=hotel_adress[0][4:x]+hotel_adress[1][4:x]+hotel_adress[2][4:27]+hotel_adress[3][4:12]
distance=distance[0][:25]+distance[1][:25]+distance[2][:23]+distance[3][:8]
description=description[0]+description[1]+description[2]+description[3]
details=details[0]+details[1]+details[2]+details[3]

# %%
len(hotel_adress)
# Out:
# 81

# %%
Hotel_name=[]
Hotel_adress=[]
Distance=[]
Rating=[]
Description=[]
Details=[]   

for x in range(len(hotel_name)):
    Hotel_name.append(hotel_name[x].text)
    Hotel_adress.append(hotel_adress[x].text)
    Distance.append(distance[x].text)
    Description.append(description[x].text)
    Details.append('https://www.booking.com'+details[x]['href'])
        #Rating.append(rating[x].text)

# %%
def clean_text(text):
    
    text = re.sub(r"\n", " ", text) 
    text = re.sub(r"\n\n\n", " ", text) 
    text = re.sub(r"Indiquer sur la carte ", "", text) 

    
    
    return text

# %%
def clean_list(coulum):
    clean=[]
    for item in coulum:
        clean.append(clean_text(item))
            
    return clean

# %%
clean_hotel=clean_list(Hotel_name)
clean_adress=clean_list(Hotel_adress)
clean_distance=clean_list(Distance)
clean_Description=clean_list(Description)
#clean_Details=clean_list(Details)

# %%
import pandas as pd
BookingSousse = pd.DataFrame(clean_hotel,columns=['Hotel_name']) 
BookingSousse["Adresse"]=clean_adress
BookingSousse["Description"]=clean_Description

BookingSousse["Distance"]=clean_distance
BookingSousse["Details_Link"]=clean_Details

BookingSousse.to_csv ('BookingSousse.csv', index = False, header=True) #Don't forget to add '.csv' at the end of the path

# %%
BookingSousse
# Out:
#                                            Hotel_name  \
# 0                                Hotel Marhaba Beach
# 1                                        Hotel Paris
# 2                         Le Monaco Hôtel & Thalasso
# 3                               Hotel Sindbad Sousse
# 4          Palmyra Aquapark Kantaoui - Families Only
# 5                             Villa de charme Sousse
# 6                                       Hôtel Medina
# 7                     L'Orient Palace Resort and Spa
# 8                          Sousse Palace Hotel & Spa
# 9                  Marhaba Royal Salem - Family Only
# 10                                  Hôtel El Faracha
# 11                               Residence Boujaafar
# 12              Mövenpick Resort & Marine Spa Sousse
# 13                                 El Mouradi Palace
# 14                            The Pearl Resort & Spa
# 15                                   Jaz Tour Khalef
# 16                         Appartement de rêve folla
# ...

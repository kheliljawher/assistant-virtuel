# %%
# Web scraping, pickle imports
import requests
from bs4 import BeautifulSoup
import pickle
import re

# %%
urls=['https://www.booking.com/searchresults.fr.html?aid=356980&label=gog235jc-1DCAIoTTgBSA1YA2jiAYgBAZgBDbgBF8gBDNgBA-gBAfgBAogCAagCA7gCx_y48wXAAgE&sid=4289cffcfd3c2269fb55c051e3e61524&sb=1&sb_lp=1&src=index&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.fr.html%3Faid%3D356980%3Blabel%3Dgog235jc-1DCAIoTTgBSA1YA2jiAYgBAZgBDbgBF8gBDNgBA-gBAfgBAogCAagCA7gCx_y48wXAAgE%3Bsid%3D4289cffcfd3c2269fb55c051e3e61524%3Bsb_price_type%3Dtotal%26%3B&ss=Nabeul&is_ski_area=0&ssne=Nabeul&ssne_untouched=Nabeul&dest_id=-727574&dest_type=city&checkin_year=&checkin_month=&checkout_year=&checkout_month=&group_adults=2&group_children=0&no_rooms=1&b_h4u_keep_filters=&from_sf=1',
     'https://www.booking.com/searchresults.fr.html?aid=356980&label=gog235jc-1DCAIoTTgBSA1YA2jiAYgBAZgBDbgBF8gBDNgBA-gBAfgBAogCAagCA7gCx_y48wXAAgE&sid=4289cffcfd3c2269fb55c051e3e61524&tmpl=searchresults&class_interval=1&dest_id=-727574&dest_type=city&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A%2CA&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=86696758a5bb001e&ss=Nabeul&ss_all=0&ssb=empty&sshis=0&ssne=Nabeul&ssne_untouched=Nabeul&top_ufis=1&rows=25&offset=25',
     'https://www.booking.com/searchresults.fr.html?aid=356980&label=gog235jc-1DCAIoTTgBSA1YA2jiAYgBAZgBDbgBF8gBDNgBA-gBAfgBAogCAagCA7gCx_y48wXAAgE&sid=4289cffcfd3c2269fb55c051e3e61524&sb=1&src=searchresults&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.fr.html%3Faid%3D356980%3Blabel%3Dgog235jc-1DCAIoTTgBSA1YA2jiAYgBAZgBDbgBF8gBDNgBA-gBAfgBAogCAagCA7gCx_y48wXAAgE%3Bsid%3D4289cffcfd3c2269fb55c051e3e61524%3Btmpl%3Dsearchresults%3Bclass_interval%3D1%3Bdest_id%3D-727574%3Bdest_type%3Dcity%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D2%3Bgroup_children%3D0%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Braw_dest_type%3Dcity%3Broom1%3DA%252CA%3Bsb_price_type%3Dtotal%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dindex%3Bsrc_elem%3Dsb%3Bsrpvid%3D1508672d441b0012%3Bss%3DNabeul%3Bss_all%3D0%3Bssb%3Dempty%3Bsshis%3D0%3Bssne%3DNabeul%3Bssne_untouched%3DNabeul%3Btop_ufis%3D1%26%3B&ss=Tunis%2C+Gouvernorat+de+Tunis%2C+Tunisie&is_ski_area=&ssne=Nabeul&ssne_untouched=Nabeul&city=-727574&checkin_year=&checkin_month=&checkout_year=&checkout_month=&group_adults=2&group_children=0&no_rooms=1&from_sf=1&ss_raw=tunis&ac_position=0&ac_langcode=fr&ac_click_type=b&dest_id=-731701&dest_type=city&iata=TUN&place_id_lat=36.800201&place_id_lon=10.186194&search_pageview_id=1508672d441b0012&search_selected=true&search_pageview_id=1508672d441b0012&ac_suggestion_list_length=5&ac_suggestion_theme_list_length=0',
     'https://www.booking.com/searchresults.fr.html?aid=356980&label=gog235jc-1DCAIoTTgBSA1YA2jiAYgBAZgBDbgBF8gBDNgBA-gBAfgBAogCAagCA7gCx_y48wXAAgE&sid=4289cffcfd3c2269fb55c051e3e61524&tmpl=searchresults&ac_click_type=b&ac_position=0&city=-727574&class_interval=1&dest_id=-731701&dest_type=city&dtdisc=0&from_sf=1&group_adults=2&group_children=0&iata=TUN&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=6f43715c3f2900ea&ss=Tunis%2C%20Gouvernorat%20de%20Tunis%2C%20Tunisie&ss_all=0&ss_raw=tunis&ssb=empty&sshis=0&ssne=Nabeul&ssne_untouched=Nabeul&top_ufis=1&rows=25&offset=25',
     'https://www.booking.com/searchresults.fr.html?aid=356980&label=gog235jc-1DCAIoTTgBSA1YA2jiAYgBAZgBDbgBF8gBDNgBA-gBAfgBAogCAagCA7gCx_y48wXAAgE&sid=4289cffcfd3c2269fb55c051e3e61524&tmpl=searchresults&ac_click_type=b&ac_position=0&city=-727574&class_interval=1&dest_id=-731701&dest_type=city&from_sf=1&group_adults=2&group_children=0&iata=TUN&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=a6be716a99080033&ss=Tunis%2C%20Gouvernorat%20de%20Tunis%2C%20Tunisie&ss_raw=tunis&ssb=empty&ssne=Nabeul&ssne_untouched=Nabeul&top_ufis=1&rows=25&offset=50',
     'https://www.booking.com/searchresults.fr.html?aid=356980&label=gog235jc-1DCAIoTTgBSA1YA2jiAYgBAZgBDbgBF8gBDNgBA-gBAfgBAogCAagCA7gCx_y48wXAAgE&sid=4289cffcfd3c2269fb55c051e3e61524&tmpl=searchresults&ac_click_type=b&ac_position=0&city=-727574&class_interval=1&dest_id=-731701&dest_type=city&dtdisc=0&from_sf=1&group_adults=2&group_children=0&iata=TUN&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=dbac71780643007e&ss=Tunis%2C%20Gouvernorat%20de%20Tunis%2C%20Tunisie&ss_all=0&ss_raw=tunis&ssb=empty&sshis=0&ssne=Nabeul&ssne_untouched=Nabeul&top_ufis=1&rows=25&offset=75',
     'https://www.booking.com/searchresults.fr.html?aid=356980&label=gog235jc-1DCAIoTTgBSA1YA2jiAYgBAZgBDbgBF8gBDNgBA-gBAfgBAogCAagCA7gCx_y48wXAAgE&sid=4289cffcfd3c2269fb55c051e3e61524&tmpl=searchresults&ac_click_type=b&ac_position=0&city=-727574&class_interval=1&dest_id=-731701&dest_type=city&from_sf=1&group_adults=2&group_children=0&iata=TUN&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=a10d718685fa00cb&ss=Tunis%2C%20Gouvernorat%20de%20Tunis%2C%20Tunisie&ss_raw=tunis&ssb=empty&ssne=Nabeul&ssne_untouched=Nabeul&top_ufis=1&rows=25&offset=100',
     'https://www.booking.com/searchresults.fr.html?aid=356980&label=gog235jc-1DCAIoTTgBSA1YA2jiAYgBAZgBDbgBF8gBDNgBA-gBAfgBAogCAagCA7gCx_y48wXAAgE&sid=4289cffcfd3c2269fb55c051e3e61524&tmpl=searchresults&ac_click_type=b&ac_position=0&city=-727574&class_interval=1&dest_id=-731701&dest_type=city&dtdisc=0&from_sf=1&group_adults=2&group_children=0&iata=TUN&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=4f2671904c5f0120&ss=Tunis%2C%20Gouvernorat%20de%20Tunis%2C%20Tunisie&ss_all=0&ss_raw=tunis&ssb=empty&sshis=0&ssne=Nabeul&ssne_untouched=Nabeul&top_ufis=1&rows=25&offset=125',
     'https://www.booking.com/searchresults.fr.html?aid=356980&label=gog235jc-1DCAIoTTgBSA1YA2jiAYgBAZgBDbgBF8gBDNgBA-gBAfgBAogCAagCA7gCx_y48wXAAgE&sid=4289cffcfd3c2269fb55c051e3e61524&tmpl=searchresults&ac_click_type=b&ac_position=0&city=-727574&class_interval=1&dest_id=-731701&dest_type=city&from_sf=1&group_adults=2&group_children=0&iata=TUN&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=b46671999197009d&ss=Tunis%2C%20Gouvernorat%20de%20Tunis%2C%20Tunisie&ss_raw=tunis&ssb=empty&ssne=Nabeul&ssne_untouched=Nabeul&top_ufis=1&rows=25&offset=150']

# %%
def url_to_transcript(url):
    response= requests.get(url)
    soup = BeautifulSoup(response.content,"html.parser")

    regex = re.compile('floatlef')
    hotel_name=soup.find_all('span',attrs={'class': 'sr-hotel__name'})  
    hotel_adress=soup.find_all('a',attrs={'class': 'bui-link'})  
    distance=soup.find_all('span',attrs={'data-bui-component': 'Tooltip','data-tooltip-position':'top'})
    hotel_desc=soup.find_all('div',attrs={'class': 'hotel_desc'})
    detail=soup.find_all('a',attrs={'class': 'hotel_name_link url'})

        
    return hotel_name,hotel_adress,distance,hotel_desc,detail

# %%
booking = [url_to_transcript(u) for u in urls]

# %%
len(urls)
# Out:
# 9

# %%
hotel_name=[]
hotel_adress=[]
distance=[]
description=[]
details=[]
for item in booking:
    hotel_name.append(item[0])
    hotel_adress.append(item[1])
    distance.append(item[2])
    description.append(item[3])
    details.append(item[4])

# %%
len(distance[4][:x])
# Out:
# 26

# %%
x=len(hotel_name[0])+4

hotel_name=hotel_name[0]+hotel_name[1]+hotel_name[2]+hotel_name[3]+hotel_name[4]+hotel_name[5]+hotel_name[6]+hotel_name[7]+hotel_name[8]
hotel_adress=hotel_adress[0][4:x]+hotel_adress[1][4:17]+hotel_adress[2][4:x]+hotel_adress[3][4:x]+hotel_adress[4][4:x]+hotel_adress[5][4:x]+hotel_adress[6][4:x]+hotel_adress[7][4:x]+hotel_adress[8][4:17]
distance=distance[0][:25]+distance[1][:13]+distance[2][:25][:25]+distance[3]+distance[4][:25]+distance[5][:25]+distance[6][:25]+distance[7]+distance[8]
description=description[0]+description[1]+description[2]+description[3]+description[4]+description[5]+description[6]+description[7]+description[8]
details=details[0]+details[1]+details[2]+details[3]+details[4]+details[5]+details[6]+details[7]+details[8]

# %%
len(distance)
# Out:
# 201

# %%
x=len(hotel_name[0])+4
hotel_name=hotel_name[0]+hotel_name[1]+hotel_name[2]+hotel_name[3]+hotel_name[4]+hotel_name[5]+hotel_name[6]
hotel_adress=hotel_adress[0][4:x]+hotel_adress[1][4:x]+hotel_adress[2][4:x]+hotel_adress[3][4:x]+hotel_adress[4][4:x]+hotel_adress[5][4:x]+hotel_adress[6][4:x]+hotel_adress[7][4:x]+hotel_adress[8][4:17]
description=description[0]+description[1]+description[2]+description[3]+description[4]+hotel_desc[5]+hotel_desc[6]

# %%
len(hotel_desc)
# Out:
# 169

# %%
Hotel_name=[]
Hotel_adress=[]
Distance=[]
Rating=[]
Description=[]
Details=[]   

for x in range(len(hotel_name)):
    Hotel_name.append(hotel_name[x].text)
    Hotel_adress.append(hotel_adress[x].text)
    Distance.append(distance[x].text)
    Description.append(description[x].text)
    Details.append('https://www.booking.com'+details[x]['href'])
        #Rating.append(rating[x].text)

# %%
len(Description)
# Out:
# 169

# %%
def clean_text(text):
    
    text = re.sub(r"\n", "", text) 
    text = re.sub(r"\n\n\n", " ", text) 
    text = re.sub(r"Indiquer sur la carte ", "", text) 

    
    
    return text

# %%
def clean_list(coulum):
    clean=[]
    for item in coulum:
        clean.append(clean_text(item))
            
    return clean

# %%
clean_hotel=clean_list(Hotel_name)
clean_adress=clean_list(Hotel_adress)
clean_distance=clean_list(Distance)
clean_Description=clean_list(Description)
#clean_Details=clean_list(Details)

# %%
clean_Details=clean_list(Details)

# %%
import pandas as pd 
Booking = pd.DataFrame(clean_hotel,columns=['Hotel_name']) 
Booking["Adresse"]=clean_adress
Booking["Distance"]=clean_distance

# %%
import pandas as pd
Booking = pd.DataFrame(clean_hotel,columns=['Hotel_name']) 
Booking["Adresse"]=clean_adress
Booking["Description"]=clean_Description

Booking["Distance"]=clean_distance
Booking["Details_Link"]=clean_Details

Booking.to_csv ('BookingSousse.csv', index = False, header=True) #Don't forget to add '.csv' at the end of the path

# %%
df=pd.read_csv('Booking.csv')

df
# Out:
#                                             Hotel_name  \
# 0                                       Hotel Byzance
# 1                  appartement de luxe près de la mer
# 2                     L'auberge de la jeunesse Nabeul
# 3                                 Palmyra Club Nabeul
# 4                    Khayam Garden Beach Resort & Spa
# 5                                     Les Vagues Home
# 6                         Apparemment standing Nabeul
# 7                                     Douja Apartment
# 8                      Ikamet Rihab at Hammamet North
# 9                              Résidence kelibia wave
# 10                                          Dar Sabri
# 11                                          Dar Taieb
# 12                             La Maison Des Oliviers
# 13                                      Les Pyramides
# 14                              Petit coin de paradis
# 15                   ARTY Apartment Residence Yasmine
# ...
